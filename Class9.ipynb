# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt  ### pyplot is a package
x = [1,2,3,4]
y = [1,2,3,4]
plt.plot(x,y)
plt.show()
## plotting a linear function

# %%
import numpy as np
x = np.arange(0.0,6.0,0.01)
### plotting non-linear curves

# %%
### plotting multiple lines
x = np.arange(1,10)
y1 = x**2
y2 = x + 50
y3 = x*10
plt.plot(x,y1,color="green")
plt.plot(x,y2,color="orange")
plt.plot(x,y3,color="red")
plt.xlabel("X range")
plt.ylabel("Values of Y ")
plt.grid(True)
plt.minorticks_on()

# %%
### scatter plot
## Missile test results, distance covered and accuracy of hitting the target

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D  ### different package used
import random
fig = pyplot.figure()
ax = Axes3D(fig)

sequence_containing_x_vals = list(range(0,100))
sequence_containing_y_vals = list(range(0, 100))
sequence_containing_z_vals =list(range(0,100))

random.shuffle(sequence_containing_x_vals)
random.shuffle(sequence_containing_y_vals)
random.shuffle(sequence_containing_z_vals)

ax.scatter(sequence_containing_x_vals, sequence_containing_y_vals,sequence_containing_z_vals)
ax.set_xlabel('Speed')
ax.set_ylabel('Distance')
ax.set_zlabel('Accuracy')
pyplot.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt

objects =('Python', 'C++', 'Java', 'Perl', 'Scala', "Lisp")
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.barh(y_pos,performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Usage')
plt.title('Programming language usage')
plt.show()

# %%
## Pie Chart
import matplotlib.pyplot as plt
percentage = [60,30,10]
language = ["Python", "Java", "C++"]
plt.pie(percentage,labels=language)
plt.title("Simple Pie Chart")
plt.show()

## D3.JS

# %%
student_name = ["John","Sahil","Monica","Lara"]
index = np.arange(len(student_name))
marks = [75,98,53,70]
plt.bar(index,marks)
plt.xlabel("Student Name")
plt.ylabel("Student Performance")
plt.xticks(index,student_name)
plt.show()
